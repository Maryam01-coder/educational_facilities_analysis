# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("facilities_records.csv", encoding="latin1")
df.head(10)
# Out:
# C:\Users\MARYAM\AppData\Local\Temp\ipykernel_1044\2802892573.py:1: DtypeWarning: Columns (0: improved_water_supply, 1: improved_sanitation, 2: phcn_electricity) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("facilities_records.csv", encoding="latin1")
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
# 5           Nomadic Paiko Kore                           Primary school only
# 6                 Nomadic Jayi                           Primary school only
# ...
