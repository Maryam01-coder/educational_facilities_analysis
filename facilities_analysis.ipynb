# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# **DATA INSPECTION**

# %%
df = pd.read_csv("uncleaned_facilities_records.csv")
df.head(10)
# Out:
# C:\Users\MARYAM\AppData\Local\Temp\ipykernel_12156\1773106388.py:1: DtypeWarning: Columns (0: improved_water_supply, 1: improved_sanitation, 2: phcn_electricity) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("uncleaned_facilities_records.csv")
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
# 5           Nomadic Paiko Kore                           Primary school only
# 6                 Nomadic Jayi                           Primary school only
# 7              Nomadic Kutunku                           Primary school only
# 8       Bargada Primary School                           Primary school only
# 9          Macbeth Intl School  Primary and Junior Secondary school combined
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# 0                  True                True                        False
# 1                 False               False                          NaN
# 2                  True                True                        False
# 3                 False                True                        False
# 4                 False                True                         True
# 5                  True                True                         True
# 6                  True                True                         True
# 7                  True                True                        False
# 8                 False                True                        False
# 9                  True                True                         True
#
#    num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# 0                 9.0                 9.0               776.0
# 1                 NaN                 NaN                 NaN
# 2                 9.0                11.0               283.0
# 3                 4.0                 5.0               247.0
# 4                 4.0                 8.0                66.0
# 5                 4.0                 6.0               120.0
# 6                 4.0                 4.0               152.0
# 7                 7.0                10.0               245.0
# 8                 4.0                 5.0               181.0
# 9                 3.0                 6.0                80.0
#
#    num_classrms_total phcn_electricity  ...   community     ward  management  \
# 0                12.0            False  ...       Swali        3      public
# 1                 NaN            False  ...       Mpape    Dutse     private
# 2                 9.0            False  ...      Pabeyi     Dobi      public
# 3                 7.0            False  ...     Pagadna     Dobi      public
# 4                10.0             True  ...       Mpape    Dutse     private
# 5                 6.0            False  ...  Paiko Kore    Paiko      public
# 6                 9.0            False  ...        Jayi     Dobi      public
# 7                10.0             True  ...     Kutunku  Kutunku      public
# 8                10.0            False  ...     Bargada    Paiko      public
# 9                 6.0            False  ...     Byazhin  Byazhin     private
#
#       sector   formhub_photo_id  \
# 0  education  1393404015008.jpg
# 1  education  1396960914896.jpg
# 2  education  1397575395444.jpg
# 3  education  1398262573409.jpg
# 4  education  1396959110576.jpg
# 5  education  1398330459520.jpg
# 6  education  1397572115063.jpg
# 7  education  1398345111978.jpg
# 8  education  1398340786686.jpg
# 9  education  1397485980654.jpg
#
#                                              gps  \
# 0                 4.91691036 6.27412844 31.5 5.0
# 1  9.140918333333333 7.496761666666667 697.0 4.5
# 2          9.174855 7.0220616666666675 236.8 5.0
# 3  9.115846666666666 6.962314999999999 216.5 4.4
# 4           9.141155 7.499665000000001 693.2 4.7
# 5           8.99146 7.0096750000000005 170.9 5.0
# 6  9.204203333333334 7.015148333333333 271.4 4.5
# 7  8.934686666666666 7.056360000000001 174.9 4.6
# 8  8.921268333333334 6.959628333333335 161.8 4.3
# 9           9.19196 7.3325966666666655 455.2 3.8
#
#                               survey_id       unique_lga  latitude longitude
# 0  51885096-65a1-4f1f-8c2a-3b11d9ae40bb  bayelsa_yenagoa  4.916910  6.274128
# 1  7f3ea41a-e4cb-41dd-85fc-5fa54c42d09f        fct_bwari  9.140918  7.496762
# 2  56f2e625-ec43-4c39-97a8-d6379dceefa2   fct_gwagwalada  9.174855  7.022062
# 3  2932eda8-64b1-4068-8412-3b2e099062fc   fct_gwagwalada  9.115847  6.962315
# 4  e17acb1e-364a-4a90-9384-0d612bb240c5        fct_bwari  9.141155  7.499665
# 5  28d8fe5a-7a18-4d17-9f64-7ae095eb1c50   fct_gwagwalada  8.991460  7.009675
# 6  31381276-73f9-4e30-acde-bec286919256   fct_gwagwalada  9.204203  7.015148
# 7  76a5fbc9-6723-467a-939d-703a3702ec53   fct_gwagwalada  8.934687  7.056360
# 8  6bd36fb3-704a-49ad-a96a-b25b24af78d3   fct_gwagwalada  8.921268  6.959628
# 9  7e344ad8-c442-4138-a869-6ce98794beaa        fct_bwari  9.191960  7.332597
#
# [10 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98667 entries, 0 to 98666
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 98452 non-null  str
#  1   facility_type_display         97764 non-null  str
#  2   improved_water_supply         98388 non-null  object
#  3   improved_sanitation           98370 non-null  object
#  4   chalkboard_each_classroom_yn  96506 non-null  object
#  5   num_tchrs_with_nce            95137 non-null  float64
#  6   num_tchr_full_time            96503 non-null  float64
#  7   num_students_total            93405 non-null  float64
#  8   num_classrms_total            95375 non-null  float64
#  9   phcn_electricity              98390 non-null  object
#  10  num_toilets_total             95705 non-null  float64
#  11  num_students_male             94292 non-null  float64
#  12  num_students_female           94321 non-null  float64
#  13  num_tchrs_male                94987 non-null  float64
#  14  num_tchrs_female              95348 non-null  float64
#  15  date_of_survey                98667 non-null  str
#  16  education_type                98446 non-null  str
#  17  facility_id                   98667 non-null  str
#  18  community                     98429 non-null  str
#  19  ward                          97896 non-null  str
#  20  management                    97444 non-null  str
#  21  sector                        98667 non-null  str
#  22  formhub_photo_id              98667 non-null  str
#  23  gps                           98667 non-null  str
#  24  survey_id                     98667 non-null  str
#  25  unique_lga                    98666 non-null  str
#  26  latitude                      98667 non-null  float64
#  27  longitude                     98667 non-null  float64
# dtypes: float64(11), object(4), str(13)
# memory usage: 41.3+ MB

# %%
print(df.shape)
# Out:
# (98667, 28)

# %%
df.describe()
# Out:
#        num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# count        95137.000000        96503.000000        93405.000000
# mean             7.017922           11.666197          335.406306
# std              8.045479           14.033793          343.354223
# min              0.000000            0.000000            0.000000
# 25%              2.000000            4.000000          118.000000
# 50%              5.000000            8.000000          223.000000
# 75%              9.000000           14.000000          419.000000
# max            100.000000          899.000000         2355.000000
#
#        num_classrms_total  num_toilets_total  num_students_male  \
# count        95375.000000       95705.000000       94292.000000
# mean             8.443512           2.546722         187.804628
# std              7.110507           5.768857         257.891030
# min              0.000000           0.000000           0.000000
# 25%              4.000000           0.000000          59.000000
# 50%              6.000000           0.000000         114.000000
# 75%             11.000000           4.000000         220.000000
# max            514.000000         418.000000        7677.000000
#
#        num_students_female  num_tchrs_male  num_tchrs_female      latitude  \
# count         94321.000000    94987.000000      95348.000000  98667.000000
# mean            169.837438        5.723583          5.957985      8.636626
# std             227.880995        6.205914          8.519480      2.403356
# min               0.000000        0.000000          0.000000      4.280918
# 25%              50.000000        2.000000          0.000000      6.671873
# 50%             100.000000        4.000000          3.000000      8.140478
# 75%             200.000000        7.000000          8.000000     10.631606
# max            6689.000000      100.000000        100.000000     13.875585
#
#           longitude
# count  98667.000000
# mean       7.183757
# std        2.353375
# min        2.707594
# 25%        5.327685
# 50%        7.303945
# 75%        8.566094
# max       14.636391

# %%
#Missing values
df.isnull().sum()
# Out:
# facility_name                    215
# facility_type_display            903
# improved_water_supply            279
# improved_sanitation              297
# chalkboard_each_classroom_yn    2161
# num_tchrs_with_nce              3530
# num_tchr_full_time              2164
# num_students_total              5262
# num_classrms_total              3292
# phcn_electricity                 277
# num_toilets_total               2962
# num_students_male               4375
# num_students_female             4346
# num_tchrs_male                  3680
# num_tchrs_female                3319
# date_of_survey                     0
# education_type                   221
# facility_id                        0
# community                        238
# ward                             771
# management                      1223
# sector                             0
# formhub_photo_id                   0
# gps                                0
# survey_id                          0
# unique_lga                         1
# latitude                           0
# longitude                          0
# dtype: int64

# %%
#checking incorrect data types
print(df.dtypes)
# Out:
# facility_name                       str
# facility_type_display               str
# improved_water_supply            object
# improved_sanitation              object
# chalkboard_each_classroom_yn     object
# num_tchrs_with_nce              float64
# num_tchr_full_time              float64
# num_students_total              float64
# num_classrms_total              float64
# phcn_electricity                 object
# num_toilets_total               float64
# num_students_male               float64
# num_students_female             float64
# num_tchrs_male                  float64
# num_tchrs_female                float64
# date_of_survey                      str
# education_type                      str
# facility_id                         str
# community                           str
# ward                                str
# management                          str
# sector                              str
# formhub_photo_id                    str
# gps                                 str
# survey_id                           str
# unique_lga                          str
# latitude                        float64
# longitude                       float64
# dtype: object

# %%
#checking unique values of coloumns - inconsistent values
print(df["improved_water_supply"].unique())
print(df["improved_sanitation"].unique())
print(df["chalkboard_each_classroom_yn"].unique())
print(df["phcn_electricity"].unique())
print(df["date_of_survey"].unique())
# Out:
# [True False nan]
# [True False nan]
# [False nan True]
# [False True nan]
# <ArrowStringArray>
# ['04/03/2014', '02/05/2014', '25/04/2014', '21/04/2014', '28/04/2014',
#  '05/03/2014', '27/02/2014', '28/02/2014', '11/04/2014', '09/04/2014',
#  ...
#  '09/03/2014', '27/11/2010', '05/07/2012', '01/09/2012', '20/04/2012',
#  '14/05/2012', '19/09/2012', '06/03/2011', '06/07/2014', '30/06/2014']
# Length: 361, dtype: str

# %% [markdown]
# **DATA CLEANING**

# %%
#Handling missing values 
df = df.dropna()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86257 entries, 0 to 86256
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 86257 non-null  str
#  1   facility_type_display         86257 non-null  str
#  2   improved_water_supply         86257 non-null  object
#  3   improved_sanitation           86257 non-null  object
#  4   chalkboard_each_classroom_yn  86257 non-null  object
#  5   num_tchrs_with_nce            86257 non-null  float64
#  6   num_tchr_full_time            86257 non-null  float64
#  7   num_students_total            86257 non-null  float64
#  8   num_classrms_total            86257 non-null  float64
#  9   phcn_electricity              86257 non-null  object
#  10  num_toilets_total             86257 non-null  float64
#  11  num_students_male             86257 non-null  float64
#  12  num_students_female           86257 non-null  float64
#  13  num_tchrs_male                86257 non-null  float64
#  14  num_tchrs_female              86257 non-null  float64
#  15  date_of_survey                86257 non-null  str
#  16  education_type                86257 non-null  str
#  17  facility_id                   86257 non-null  str
#  18  community                     86257 non-null  str
#  19  ward                          86257 non-null  str
#  20  management                    86257 non-null  str
#  21  sector                        86257 non-null  str
#  22  formhub_photo_id              86257 non-null  str
#  23  gps                           86257 non-null  str
#  24  survey_id                     86257 non-null  str
#  25  unique_lga                    86257 non-null  str
#  26  latitude                      86257 non-null  float64
#  27  longitude                     86257 non-null  float64
# dtypes: float64(11), object(4), str(13)
# memory usage: 36.1+ MB

# %% [markdown]
# **Reason for dropping null values**
# I decided to drop all null values in dataset because;
# * A very relevant amount of data still remains after the removal as only **12.57%** of the data was removed.
# * Filling the null values in some columns with either the mode value or average will affect the analysis of the data and can lead to wrong insights.

# %%
#fixing datatypes
df["improved_water_supply"] = df["improved_water_supply"].astype(bool)
df["improved_sanitation"] = df["improved_sanitation"].astype(bool)
df["chalkboard_each_classroom_yn"] = df["chalkboard_each_classroom_yn"].astype(bool)
df["phcn_electricity"] = df["phcn_electricity"].astype(bool)

# %%
#cleaning date value
from dateutil import parser

def clean_date(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NaT

df["date_of_survey"] = df["date_of_survey"].apply(clean_date)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86257 entries, 0 to 86256
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 86257 non-null  str
#  1   facility_type_display         86257 non-null  str
#  2   improved_water_supply         86257 non-null  bool
#  3   improved_sanitation           86257 non-null  bool
#  4   chalkboard_each_classroom_yn  86257 non-null  bool
#  5   num_tchrs_with_nce            86257 non-null  float64
#  6   num_tchr_full_time            86257 non-null  float64
#  7   num_students_total            86257 non-null  float64
#  8   num_classrms_total            86257 non-null  float64
#  9   phcn_electricity              86257 non-null  bool
#  10  num_toilets_total             86257 non-null  float64
#  11  num_students_male             86257 non-null  float64
#  12  num_students_female           86257 non-null  float64
#  13  num_tchrs_male                86257 non-null  float64
#  14  num_tchrs_female              86257 non-null  float64
#  15  date_of_survey                86257 non-null  datetime64[us]
#  16  education_type                86257 non-null  str
#  17  facility_id                   86257 non-null  str
#  18  community                     86257 non-null  str
#  19  ward                          86257 non-null  str
#  20  management                    86257 non-null  str
#  21  sector                        86257 non-null  str
#  22  formhub_photo_id              86257 non-null  str
#  23  gps                           86257 non-null  str
#  24  survey_id                     86257 non-null  str
#  25  unique_lga                    86257 non-null  str
#  26  latitude                      86257 non-null  float64
#  27  longitude                     86257 non-null  float64
# dtypes: bool(4), datetime64[us](1), float64(11), str(12)
# memory usage: 33.0 MB

# %%
#droping unnecessary columns
df = df.drop(columns=["formhub_photo_id", "survey_id", "gps", "facility_id"])
df.head()
# Out:
#                  facility_name facility_type_display  improved_water_supply  \
# 0                    CPS SWALI   Primary school only                   True
# 1  L.E.A Primary School Pabeyi   Primary school only                   True
# 2   L.E.A.PrimarySchoolPagadna   Primary school only                  False
# 3              Syflora Academy   Primary school only                  False
# 4           Nomadic Paiko Kore   Primary school only                   True
#
#    improved_sanitation  chalkboard_each_classroom_yn  num_tchrs_with_nce  \
# 0                 True                         False                 9.0
# 1                 True                         False                 9.0
# 2                 True                         False                 4.0
# 3                 True                          True                 4.0
# 4                 True                          True                 4.0
#
#    num_tchr_full_time  num_students_total  num_classrms_total  \
# 0                 9.0               776.0                12.0
# 1                11.0               283.0                 9.0
# 2                 5.0               247.0                 7.0
# 3                 8.0                66.0                10.0
# 4                 6.0               120.0                 6.0
#
#    phcn_electricity  ...  num_tchrs_female  date_of_survey  education_type  \
# 0             False  ...               4.0      2014-03-04     formal_only
# 1             False  ...               2.0      2014-05-02     formal_only
# 2             False  ...               0.0      2014-04-25     formal_only
# 3              True  ...               6.0      2014-04-25     formal_only
# 4             False  ...               1.0      2014-04-25     formal_only
#
#     community   ward management     sector       unique_lga  latitude  \
# 0       Swali      3     public  education  bayelsa_yenagoa  4.916910
# 1      Pabeyi   Dobi     public  education   fct_gwagwalada  9.174855
# 2     Pagadna   Dobi     public  education   fct_gwagwalada  9.115847
# 3       Mpape  Dutse    private  education        fct_bwari  9.141155
# 4  Paiko Kore  Paiko     public  education   fct_gwagwalada  8.991460
#
#   longitude
# 0  6.274128
# 1  7.022062
# 2  6.962315
# 3  7.499665
# 4  7.009675
#
# [5 rows x 24 columns]

# %%
#Validate Numeric Columns
numeric_cols = [
    'num_tchrs_with_nce',
    'num_tchr_full_time',
    'num_students_total',
    'num_classrms_total',
    'num_toilets_total'
]

df[numeric_cols].describe()
# Out:
#        num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# count        86257.000000        86257.000000        86257.000000
# mean             6.958079           11.446943          337.735430
# std              7.701503           11.168869          344.254834
# min              0.000000            0.000000            0.000000
# 25%              2.000000            5.000000          120.000000
# 50%              5.000000            8.000000          225.000000
# 75%              9.000000           14.000000          420.000000
# max             98.000000          186.000000         2355.000000
#
#        num_classrms_total  num_toilets_total
# count        86257.000000       86257.000000
# mean             8.265938           2.527493
# std              6.808815           5.401288
# min              0.000000           0.000000
# 25%              4.000000           0.000000
# 50%              6.000000           1.000000
# 75%             10.000000           4.000000
# max            514.000000         418.000000

# %%
#checking for negative values 
(df[numeric_cols] < 0).sum()
# Out:
# num_tchrs_with_nce    0
# num_tchr_full_time    0
# num_students_total    0
# num_classrms_total    0
# num_toilets_total     0
# dtype: int64

# %%
df["ward"].unique()
# Out:
# <ArrowStringArray>
# [                   '3',                 'Dobi',                'Dutse',
#                 'Paiko',              'Kutunku',              'Byazhin',
#                 'Kubwa',                    '4',          'Akpet abini',
#                  'Ehom',
#  ...
#        'Temidire ;Sabo',       'AYETORO WARD 2',     'Oke Odo Obantoko',
#                 'AGADO',               'BADARI',                 'Raga',
#             'Tube ward', 'Kyola nomadic school',          'Gidan Agwai',
#      'Adiabo Efut Ward']
# Length: 22012, dtype: str

# %%
#handling input that are only numbers
df["ward"] = df["ward"].str.replace(
    r"^\s*(\d+)\s*$",
    r"Ward \1",
    regex=True
)
df.head()
# Out:
#                  facility_name facility_type_display  improved_water_supply  \
# 0                    CPS SWALI   Primary school only                   True
# 1  L.E.A Primary School Pabeyi   Primary school only                   True
# 2   L.E.A.PrimarySchoolPagadna   Primary school only                  False
# 3              Syflora Academy   Primary school only                  False
# 4           Nomadic Paiko Kore   Primary school only                   True
#
#    improved_sanitation  chalkboard_each_classroom_yn  num_tchrs_with_nce  \
# 0                 True                         False                 9.0
# 1                 True                         False                 9.0
# 2                 True                         False                 4.0
# 3                 True                          True                 4.0
# 4                 True                          True                 4.0
#
#    num_tchr_full_time  num_students_total  num_classrms_total  \
# 0                 9.0               776.0                12.0
# 1                11.0               283.0                 9.0
# 2                 5.0               247.0                 7.0
# 3                 8.0                66.0                10.0
# 4                 6.0               120.0                 6.0
#
#    phcn_electricity  ...  num_tchrs_female  date_of_survey  education_type  \
# 0             False  ...               4.0      2014-03-04     formal_only
# 1             False  ...               2.0      2014-05-02     formal_only
# 2             False  ...               0.0      2014-04-25     formal_only
# 3              True  ...               6.0      2014-04-25     formal_only
# 4             False  ...               1.0      2014-04-25     formal_only
#
#     community    ward management     sector       unique_lga  latitude  \
# 0       Swali  Ward 3     public  education  bayelsa_yenagoa  4.916910
# 1      Pabeyi    Dobi     public  education   fct_gwagwalada  9.174855
# 2     Pagadna    Dobi     public  education   fct_gwagwalada  9.115847
# 3       Mpape   Dutse    private  education        fct_bwari  9.141155
# 4  Paiko Kore   Paiko     public  education   fct_gwagwalada  8.991460
#
#   longitude
# 0  6.274128
# 1  7.022062
# 2  6.962315
# 3  7.499665
# 4  7.009675
#
# [5 rows x 24 columns]

# %%
#handling values with roman numerals
roman_to_number = {
    "I": "1",
    "II": "2",
    "III": "3",
    "IV": "4",
    "V": "5",
    "VI": "6",
    "VII": "7",
    "VIII": "8",
    "IX": "9",
    "X": "10"
}

for roman, number in roman_to_number.items():
    df["ward"] = df["ward"].str.replace(
        rf"^Ward\s+{roman}$",
        f"Ward {number}",
        regex=True
    )

# %%
#standardizing texts
df["ward"] = (df["ward"]
    .str.strip()
    .str.title()
    .str.replace("Gra", "GRA", regex=False)
)

df["community"] = (df["community"]
    .str.strip()
    .str.title()
    .str.replace("Gra", "GRA", regex=False)
)

# %%
#creating new columns 
df["student_to_teacher_ratio"] = (df['num_students_total'] / df['num_tchr_full_time']).round(2)
df["total_teachers"] = (df["num_tchrs_with_nce"] + df["num_tchr_full_time"])
df["facility_density"] = df.groupby("ward")["ward"].transform("count")

# %%
df.head()
# Out:
#                  facility_name facility_type_display  improved_water_supply  \
# 0                    CPS SWALI   Primary school only                   True
# 1  L.E.A Primary School Pabeyi   Primary school only                   True
# 2   L.E.A.PrimarySchoolPagadna   Primary school only                  False
# 3              Syflora Academy   Primary school only                  False
# 4           Nomadic Paiko Kore   Primary school only                   True
#
#    improved_sanitation  chalkboard_each_classroom_yn  num_tchrs_with_nce  \
# 0                 True                         False                 9.0
# 1                 True                         False                 9.0
# 2                 True                         False                 4.0
# 3                 True                          True                 4.0
# 4                 True                          True                 4.0
#
#    num_tchr_full_time  num_students_total  num_classrms_total  \
# 0                 9.0               776.0                12.0
# 1                11.0               283.0                 9.0
# 2                 5.0               247.0                 7.0
# 3                 8.0                66.0                10.0
# 4                 6.0               120.0                 6.0
#
#    phcn_electricity  ...   community    ward  management     sector  \
# 0             False  ...       Swali  Ward 3      public  education
# 1             False  ...      Pabeyi    Dobi      public  education
# 2             False  ...     Pagadna    Dobi      public  education
# 3              True  ...       Mpape   Dutse     private  education
# 4             False  ...  Paiko Kore   Paiko      public  education
#
#         unique_lga  latitude longitude student_to_teacher_ratio  \
# 0  bayelsa_yenagoa  4.916910  6.274128                    86.22
# 1   fct_gwagwalada  9.174855  7.022062                    25.73
# 2   fct_gwagwalada  9.115847  6.962315                    49.40
# 3        fct_bwari  9.141155  7.499665                     8.25
# 4   fct_gwagwalada  8.991460  7.009675                    20.00
#
#   total_teachers facility_density
# 0           18.0             1458
# 1           20.0               25
# 2            9.0               25
# 3           12.0               63
# 4           10.0                8
#
# [5 rows x 27 columns]

# %%
df.to_csv("cleaned_facilities_records.csv", index=False)

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
#What are the most common types of educational facilities?
df.groupby("facility_type_display")["facility_type_display"].count().sort_values(ascending=False)
# Out:
# facility_type_display
# Primary Only                                            25210
# Pre-primary and Primary                                 16717
# Primary school only                                     14004
# Pre-primary and Primary school combined                  9420
# Junior Secondary Only                                    4538
# Junior and Senior Secondary                              4435
# Junior and Senior Secondary school combined              3654
# Junior Secondary school only                             1755
# Pre-primary Only                                         1541
# Senior Secondary Only                                    1223
# Primary and Junior Secondary school combined              821
# Primary, Junior, and Senior Secondary                     800
# Primary and Junior Secondary                              794
# Primary, Junior and Senior Secondary school combined      648
# Information not available / Don't know                    476
# Adult, Vocational, or Technical                           221
# Name: facility_type_display, dtype: int64

# %%
#facility proportion
print((df["improved_water_supply"].value_counts(normalize=True) * 100).round(2))
# Out:
# improved_water_supply
# False    61.91
# True     38.09
# Name: proportion, dtype: float64

# %% [markdown]
# Only **38.09%** of the schools has improved water supply.

# %%
print((df["improved_sanitation"].value_counts(normalize=True) * 100).round(2))
# Out:
# improved_sanitation
# False    53.83
# True     46.17
# Name: proportion, dtype: float64

# %% [markdown]
# Only **46.17%** of the schools has improved sanitation.

# %%
print((df["phcn_electricity"].value_counts(normalize=True) * 100).round(2))
# Out:
# phcn_electricity
# False    75.51
# True     24.49
# Name: proportion, dtype: float64

# %% [markdown]
# Only **24.49%** of the schools has electricity.

# %%
#calculating average
print("Average students per school:", round(df["num_students_total"].mean(), 2))
print("Average teachers per school:", round(df["total_teachers"].mean(), 2))
# Out:
# Average students per school: 337.74
# Average teachers per school: 18.41

# %%
#comparing public vs private
df.groupby("management")["num_students_total"].sum().sort_values(ascending=False)
# Out:
# management
# public         24818931.0
# private         3955117.0
# faith_based      353959.0
# none               4038.0
# Name: num_students_total, dtype: float64

# %%
df.groupby("management")["total_teachers"].sum().sort_values(ascending=False)
# Out:
# management
# public         1190377.0
# private         366223.0
# faith_based      30628.0
# none               334.0
# Name: total_teachers, dtype: float64

# %%
(df.groupby("management")[["improved_water_supply", "improved_sanitation", "chalkboard_each_classroom_yn", "phcn_electricity"]].mean() * 100).round(2).sort_values(ascending=False, by="improved_sanitation")
# Out:
#              improved_water_supply  improved_sanitation  \
# management
# faith_based                  68.55                79.78
# private                      58.23                73.65
# public                       32.24                38.33
# none                         30.77                26.92
#
#              chalkboard_each_classroom_yn  phcn_electricity
# management
# faith_based                         36.33             52.19
# private                             58.75             52.36
# public                              43.30             16.65
# none                                65.38             23.08

# %%
df.groupby("unique_lga")["facility_name"].count().sort_values(ascending=False).reset_index()
# Out:
#             unique_lga  facility_name
# 0             ogun_ifo            529
# 1        kaduna_chikun            386
# 2          delta_uvwie            315
# 3         kaduna_igabi            308
# 4        plateau_mangu            303
# ..                 ...            ...
# 767        lagos_ikeja              9
# 768        borno_ngala              6
# 769           fct_kuje              5
# 770        jigawa_miga              4
# 771  borno_kwaya_kusar              3
#
# [772 rows x 2 columns]

# %%
print(
    (df.groupby("unique_lga")["improved_sanitation"]
        .mean() * 100)
        .round()
        .sort_values(ascending=False)
)
# Out:
# unique_lga
# kano_kano_municipal    100.0
# sokoto_sokoto_south    100.0
# lagos_kosofe            96.0
# lagos_ifako_ijaye       95.0
# ogun_ikenne             95.0
#                        ...
# oyo_saki_east            8.0
# plateau_wase             8.0
# plateau_kanam            6.0
# jigawa_miga              0.0
# borno_ngala              0.0
# Name: improved_sanitation, Length: 772, dtype: float64

# %%
print(
    (df.groupby("unique_lga")["phcn_electricity"]
        .mean() * 100)
        .round()
        .sort_values(ascending=False)
)
# Out:
# unique_lga
# lagos_kosofe              92.0
# lagos_shomolu             88.0
# lagos_ajeromi_ifelodun    88.0
# anambra_onitsha_north     84.0
# lagos_oshodi_isolo        83.0
#                           ...
# yobe_geidam                0.0
# taraba_karim_lamido        0.0
# taraba_gashaka             0.0
# taraba_lau                 0.0
# taraba_sardauna            0.0
# Name: phcn_electricity, Length: 772, dtype: float64

# %% [markdown]
# **DATA VISUALIZATION**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86257 entries, 0 to 86256
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 86257 non-null  str
#  1   facility_type_display         86257 non-null  str
#  2   improved_water_supply         86257 non-null  bool
#  3   improved_sanitation           86257 non-null  bool
#  4   chalkboard_each_classroom_yn  86257 non-null  bool
#  5   num_tchrs_with_nce            86257 non-null  float64
#  6   num_tchr_full_time            86257 non-null  float64
#  7   num_students_total            86257 non-null  float64
#  8   num_classrms_total            86257 non-null  float64
#  9   phcn_electricity              86257 non-null  bool
#  10  num_toilets_total             86257 non-null  float64
#  11  num_students_male             86257 non-null  float64
#  12  num_students_female           86257 non-null  float64
#  13  num_tchrs_male                86257 non-null  float64
#  14  num_tchrs_female              86257 non-null  float64
#  15  date_of_survey                86257 non-null  datetime64[us]
#  16  education_type                86257 non-null  str
#  17  community                     86257 non-null  str
#  18  ward                          86257 non-null  str
#  19  management                    86257 non-null  str
#  20  sector                        86257 non-null  str
#  21  unique_lga                    86257 non-null  str
#  22  latitude                      86257 non-null  float64
#  23  longitude                     86257 non-null  float64
#  24  student_to_teacher_ratio      86105 non-null  float64
#  25  total_teachers                86257 non-null  float64
#  26  facility_density              86257 non-null  int64
# dtypes: bool(4), datetime64[us](1), float64(13), int64(1), str(8)
# memory usage: 24.1 MB

# %%
#Bar chart of school types
school_type_count = df["facility_type_display"].value_counts()
fig1 = px.bar(
    x = school_type_count.values,
    y = school_type_count.index,
    title = "Distibution of School Types"
)
fig1.update_layout(
    width=1000,
    height=750,
    xaxis_title="Count",
    yaxis_title= "School Type"
)

fig1.show()

# %%
#Histogram of student population
fig2 = px.histogram(
    df,
    x="num_students_total",
    nbins=7,
    title="Distribution of Student Population"
)

fig2.update_traces(
    marker_line_color="white",
    marker_line_width=2
)

fig2.update_layout(
    xaxis_title="Number of Students",
    yaxis_title="Number of Schools",
    width=1000,
    height=600
)

fig2.show()

# %%
#Boxplot of teacher distribution
fig3 = px.box(
    df,
    y="total_teachers",
    title="Boxplot for Teachers Distribution"
)
fig3.update_layout(
    yaxis_title="Number of Teachers",
    width=800,
    height=600
)

fig3.show()

# %%
#Pie chart of water and sanitation access
# Improved Water Supply
water_counts = df['improved_water_supply'].value_counts()

fig_water = px.pie(
    names=[False, True],
    values=[
        water_counts.get(False, 0),
        water_counts.get(True, 0)],
    title='Access to Improved Water Supply'
)

fig_water.show()

# Improved Sanitation
sanitation_counts = df['improved_sanitation'].value_counts()

fig_sanitation = px.pie(
    names=[False, True],
    values=[
        sanitation_counts.get(False, 0),
        sanitation_counts.get(True, 0)
    ],
    title='Access to Improved Sanitation'
)

fig_sanitation.show()

# %%
#Map visualization using latitude and longitude
fig4 = px.scatter_map(
    df,
    lat='latitude',
    lon='longitude',
    color='phcn_electricity',
    zoom=4,
    height=600,
    title='Location of Schools'
)

fig4.update_layout(
    map_style='open-street-map',
)

fig4.show()

# %% [markdown]
# **Summary Report and Recommendations**

# %% [markdown]
# **Key Findings**
#
# The analysis shows that Nigeria has a significant educational infrastructure problem. Only **38.09%** of schools have **improved water supply**, **46.17%** have **improved sanitation**, and just **24.49%** have **electricity**. This means that many schools lack the basic facilities needed to provide a safe and effective learning environment, with electricity being the most serious gap.
#
# Primary education represents the largest share of the facilities analysed, with **25,210 Primary Only schools** and **16,717 Pre-primary and Primary schools**. This suggests that primary education should receive considerable attention when planning infrastructure improvements.
#
# The average school has about 338 students and 18 teachers, but there are large differences between schools, with some having no recorded students and others having more than 2,300 students. This shows that national averages alone can hide problems such as **overcrowding and uneven teacher distribution**.
# Public schools carry most of the education burden, serving about **24.82 million students**, compared with **3.96 million** in private schools and about **354,000** in faith-based schools. Public schools also have the largest number of teachers, with approximately 1.19 million, compared with 366,000 in private schools.
#
# However, public schools have significantly poorer infrastructure. Only 32.24% have improved water, 38.33% have improved sanitation, 43.30% have a chalkboard in each classroom, and 16.65% have electricity. In comparison, private schools have 58.23% water, 73.65% sanitation and 52.36% electricity, while faith-based schools have 68.55%, 79.78% and 52.19%, respectively. This shows a clear infrastructure gap between public and non-public schools.
# Geographic Findings
#
# Infrastructure also varies greatly across the 772 LGAs in the cleaned dataset. Some LGAs have very high coverage, while others have extremely low levels. For sanitation, Kano Municipal and Sokoto South recorded 100%, while Miga, Jigawa and Ngala, Borno recorded 0%. Several LGAs in Taraba also recorded 0% electricity access.
#
# **What Major Problems Exist?**
#
# The major problems identified are poor electricity access, inadequate water supply, poor sanitation, unequal infrastructure between public and private schools, differences between locations, uneven student-teacher distribution, and limited classroom resources. These problems affect the quality and safety of the learning environment and are particularly serious in underserved communities.
#
# **Which Regions Need the Most Attention?**
#
# The greatest attention should go to underserved LGAs, particularly in parts of Taraba, Borno, Yobe, Jigawa and Plateau, where the analysis found very low or zero access to key facilities. However, needs should be assessed at the LGA level rather than assuming that every school in a state has the same conditions. Lagos and some other LGAs perform better on certain indicators, but this does not mean they have no educational challenges.
# Priority should be based on two factors: the severity of the infrastructure gap and the number of students/facilities affected.
#
# **How Governments and NGOs Can Use the Data?**
#
# Governments and NGOs can use the data to make funding and intervention decisions more targeted. Instead of distributing resources equally, they can identify schools and LGAs with the greatest infrastructure gaps and prioritise them.
#
# For example, NGOs can target schools without improved water and sanitation, energy organisations can focus on schools without electricity, education organisations can target schools with large student populations, and teacher-support programmes can focus on schools with high student-to-teacher pressure.
#
# Because public schools serve the majority of students while having poorer infrastructure, they should receive significant attention. Funding can focus on water systems, sanitation, classrooms, teaching materials, electricity/solar power and basic digital infrastructure. Combining infrastructure conditions with student population would also help identify where investments can have the greatest impact.
#
# **Recommendations**
# 1.	Prioritise water, sanitation and electricity as immediate infrastructure needs.
# 2.	Give greater attention to public schools, which serve the largest student population but have weaker infrastructure.
# 3.	Target interventions at the LGA level based on actual need rather than using a one-size-fits-all approach.
# 4.	Use solar and other renewable energy solutions in areas with poor or unreliable grid electricity.
# 5.	Combine infrastructure gaps with student population when allocating resources.
# 6.	Improve teacher planning by considering enrolment and student-teacher pressure.
# 7.	Develop a school infrastructure priority index to rank schools according to their level of need.
# 8.	Regularly update the data so that decisions are based on current conditions.
#
# **Conclusion**
#
# A major limitation is that the dataset contains survey information from **2010–2014**, so it should not be treated as a complete picture of Nigeria's educational infrastructure today. However, it provides useful evidence of historical infrastructure gaps and demonstrates how data can be used for targeted planning.
# Overall, the analysis shows that Nigeria's education system faces serious challenges in electricity, water, sanitation and basic classroom resources, with public schools and several underserved LGAs facing the greatest difficulties. The key takeaway is that education funding should be data-driven and targeted, using school-level and LGA-level information to direct resources to the areas where they are most needed and where they can benefit the largest number of students.
